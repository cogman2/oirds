# %% [markdown]
# # 60 Label
#
# ## Create DB Configuration
# ```
# {
#    "dataDirectory": "/data/oirds",
#    "xlsInfoColumns" : [2,7,9],
#    "modes": ["VEHICLE/CAR","VEHICLE/PICK-UP","VEHICLE/TRUCK","VEHICLE/UNKNOWN","VEHICLE/VAN"],
#    "imageDirectory": "png",
#    "multiplicationFactor": 1,
#    "labelIndex": 7,
#    "resize": 128,
#    "percentageToTest":0.18
# }
# ```
#
# ## Base Solver Configuration
#
# Learning Rate is le-11
# Learning Rate is fixed
# Momentum is 0.99
# Weight Decay is 0.0005
#
# ## Base Solver Configuration
#
# ```
# {
#    "modelFileName": "/data/oird_fcn/fcn-8s-pascalcontext.caffemodel",
#    "prototxt" : "solver.prototxt",
#    "netsurgery": true,
#    "steps":15000,
#    "gpu": true
# }
# ```
#
# ## Base Network Configuration
#
# Learning only on layers upscore2,score-pool4, upsample-fused-16, score-pool3 and score59.
# Normalization false for loss function.
#
# Loss layer is as follows:
# ```
# layer {
#   name: "loss"
#   type: "SoftmaxWithLoss"
#   bottom: "score"
#   bottom: "label"
#   top: "loss"
#   loss_param {
#     normalize: false
#   }
# }
# ```
#
# ## Scenario: Ignore Back Ground
#
# Set ignore_label=0 in train_val.prototxt
#
# Final Test net loss = 0.000123357 (* 1 = 0.000123357 loss)
#
# ### Sample Stats
#
# | Image        | FP | FN | TP | TN| Wrong Label| Precision |Recall | Accuracy  | F-Score |
# |-------------|----------:|-------------:|-------------:|-------------:|-------------:|-------------:|-------------:|-------------:|-------------:|
# |19051500_513_6913_769_7169|16205.0| 0.0| 179.0| 0.0| 0.0| 0.01092529296875| 1.0| 0.01092529296875| 0.021614441828171224|
# |31741696_257_4353_513_4609|16233.0| 0.0| 151.0| 0.0| 0.0| 0.00921630859375| 1.0| 0.00921630859375| 0.01826428787420623|
# |46946744_2817_8193_3073_8449|16235.0| 0.0| 149.0| 0.0| 0.0| 0.00909423828125| 1.0| 0.00909423828125| 0.018024556946712636|
# |45922004_3073_2305_3329_2561|16134.0| 0.0| 250.0| 0.0| 0.0| 0.0152587890625| 1.0| 0.0152587890625| 0.030058915474329685|
# |31122567_2561_5377_2817_5633|16296.0| 0.0| 88.0| 0.0| 0.0| 0.00537109375| 1.0| 0.00537109375| 0.010684798445847498|
# |11946291_1_2049_257_2305|16296.0| 0.0| 88.0| 0.0| 0.0| 0.00537109375| 1.0| 0.00537109375| 0.010684798445847498|
# |11946291_6145_1281_6401_1537|16299.0| 0.0| 85.0| 0.0| 0.0| 0.00518798828125| 1.0| 0.00518798828125| 0.01032242394802356|
# |41835134_1793_3073_2049_3329|16066.0| 0.0| 318.0| 0.0| 0.0| 0.0194091796875| 1.0| 0.0194091796875| 0.03807927194347982|
#
# ### Total Stats
#
# | Image        | FP | FN | TP | TN| Wrong Label| Precision |Recall | Accuracy  | F-Score |
# |-------------|----------:|-------------:|-------------:|-------------:|-------------:|-------------:|-------------:|-------------:|-------------:|
# |Totals|10219357.0| 0.0| 102517.0| 46.0| 0.0| 0.009932014283452792| 1.0| 0.009936426556299604| 0.01966867896647392|
#
#
# ## Scenario:  Learning with FC7
#
# Convolution fc7 is learned.
#
# Final Test net output #0: loss = 0.000864353 (* 1 = 0.000864353 loss)
#
# ### Sample Stats
#
# | Image        | FP | FN | TP | TN| Wrong Label| Precision |Recall | Accuracy  | F-Score |
# |-------------|----------:|-------------:|-------------:|-------------:|-------------:|-------------:|-------------:|-------------:|-------------:|
# |04822305_2817_2049_3073_2305|19.0| 76.0| 0.0| 16289.0| 0.0| 0.0| 0.0| 0.99420166015625| 0.0|
# |04822305_2817_5121_3073_5377|94.0| 343.0| 1.0| 15946.0| 0.0| 0.010526315789473684| 0.0029069767441860465| 0.97332763671875| 0.004555808656036447|
# |04822305_2817_6657_3073_6913|61.0| 87.0| 0.0| 16236.0| 0.0| 0.0| 0.0| 0.990966796875| 0.0|
# |04822305_2817_6913_3073_7169|0.0| 90.0| 0.0| 16294.0| 0.0| 0.0| 0.0| 0.9945068359375| 0.0|
# |04822305_2817_7681_3073_7937|87.0| 85.0| 69.0| 16143.0| 0.0| 0.4423076923076923| 0.44805194805194803| 0.989501953125| 0.44516129032258067|
# |04822305_513_1281_769_1537|82.0| 135.0| 25.0| 16142.0| 0.0| 0.2336448598130841| 0.15625| 0.98675537109375| 0.18726591760299624|
# |04822305_513_3073_769_3329|19.0| 42.0| 81.0| 16242.0| 0.0| 0.81| 0.6585365853658537| 0.99627685546875| 0.726457399103139|
# |04822305_513_4097_769_4353|0.0| 122.0| 0.0| 16262.0| 0.0| 0.0| 0.0| 0.9925537109375| 0.0|
# |04822305_769_1537_1025_1793|0.0| 189.0| 0.0| 16195.0| 0.0| 0.0| 0.0| 0.98846435546875| 0.0|
# |04822305_769_3841_1025_4097|32.0| 303.0| 15.0| 16034.0| 0.0| 0.3191489361702128| 0.04716981132075472| 0.97955322265625| 0.08219178082191782|
# |49829545__1793_6913_2049_7169|0.0| 53.0| 0.0| 16331.0| 0.0| 0.0| 0.0| 0.99676513671875| 0.0|
#
# ### Total Stats
#
# | Image        | FP | FN | TP | TN| Wrong Label| Precision |Recall | Accuracy  | F-Score |
# |-------------|----------:|-------------:|-------------:|-------------:|-------------:|-------------:|-------------:|-------------:|-------------:|
# |Totals|79742.0| 85807.0| 16710.0| 10139661.0| 0.0| 0.17324679633392776| 0.16299735653598915| 0.983961414155506| 0.16796586402906985|
#
#
# ## Scenario :  Learning Fifth layer of Convolutions
#
# Learning turned on for conv5_1, conv5_2, conv5_3, fc6 and fc7.
#
# Total Test net output #0: loss = 964.242 (* 1 = 964.242 loss)
#
# ### Sample Stats
#
# | Image        | FP | FN | TP | TN| Wrong Label| Precision |Recall | Accuracy  | F-Score |
# |-------------|----------:|-------------:|-------------:|-------------:|-------------:|-------------:|-------------:|-------------:|-------------:|
# |16546686_257_4353_513_4609|57.0| 183.0| 0.0| 16144.0| 0.0| 0.0| 0.0| 0.9853515625| 0.0|
# |16546686_257_5633_513_5889|0.0| 107.0| 0.0| 16277.0| 0.0| 0.0| 0.0| 0.99346923828125| 0.0|
# |16546686_2817_2305_3073_2561|25.0| 105.0| 0.0| 16254.0| 0.0| 0.0| 0.0| 0.9920654296875| 0.0|
# |16546686_2817_8193_3073_8449|0.0| 266.0| 0.0| 16118.0| 0.0| 0.0| 0.0| 0.9837646484375| 0.0|
# |16546686_513_1_769_257|13.0| 89.0| 6.0| 16276.0| 0.0| 0.3157894736842105| 0.06315789473684211| 0.9937744140625| 0.10526315789473685|
# |16546686_513_5377_769_5633|7.0| 117.0| 0.0| 16260.0| 0.0| 0.0| 0.0| 0.992431640625| 0.0|
# |16546686_513_8705_769_8961|47.0| 95.0| 7.0| 16235.0| 0.0| 0.12962962962962962| 0.06862745098039216| 0.9913330078125| 0.08974358974358974|
# |16546686_769_8193_1025_8449|0.0| 169.0| 0.0| 16215.0| 0.0| 0.0| 0.0| 0.98968505859375| 0.0|
# |19051500_1025_1281_1281_1537|0.0| 174.0| 0.0| 16210.0| 0.0| 0.0| 0.0| 0.9893798828125| 0.0|
# |19051500_1025_1537_1281_1793|19.0| 186.0| 0.0| 16179.0| 0.0| 0.0| 0.0| 0.98748779296875| 0.0|
# |19051500_1025_5377_1281_5633|15.0| 117.0| 8.0| 16244.0| 0.0| 0.34782608695652173| 0.064| 0.991943359375| 0.10810810810810811|
#
# ### Total Stats
#
# | Image        | FP | FN | TP | TN| Wrong Label| Precision |Recall | Accuracy  | F-Score |
# |-------------|----------:|-------------:|-------------:|-------------:|-------------:|-------------:|-------------:|-------------:|-------------:|
# |Totals|33575|93410|9107|10185828|0|0.000893287|0.213368633|0.987697541|0.125441635|
#
#
# # Two Label
#
# ## Create DB Configuration
# ```
# {
#    "dataDirectory": "/data/oirds",
#    "xlsInfoColumns" : [2,7,9],
#    "modes": ["VEHICLE/CAR","VEHICLE/PICK-UP","VEHICLE/TRUCK","VEHICLE/UNKNOWN","VEHICLE/VAN"],
#    "imageDirectory": "png",
#    "multiplicationFactor": 1,
#    "resize": 128,
#    "labelIndex": 1,
#    "percentageToTest":0.18
# }
# ```
# ## Base Solver Configuration
#
# Learning Rate is le-11
# Learning Rate is fixed
# Momentum is 0.99
# Weight Decay is 0.0005
#
# ## Base Solver Configuration
#
# ```
# {
#    "modelFileName": "/data/oird_fcn/fcn-8s-pascalcontext.caffemodel",
#    "prototxt" : "solver.prototxt",
#    "netsurgery": true,
#    "steps":15000,
#    "gpu": true
# }
# ```
#
# ## Base Network Configuration
#
# Learning only on layers fc7, upscore2,score-pool4, upsample-fused-16, score-pool3 and score59.
# Normalization false for loss function.
#
# Number of outputs is 2, requiring modification/renaming of the following layers: score59, upscore2, score-pool3, score-pool3c, score-pool4, upsample-fused-16, upsample.  These layers do not have transfer learning.
#
# ## Scenario: Base
#
# Total Test net loss = 961.022 (* 1 = 961.022 loss)
# Total Test accuracy = 0.988188
#
# ### Sample Stats
#
# | Image        | FP | FN | TP | TN| Wrong Label| Precision |Recall | Accuracy  | F-Score |
# |-------------|----------:|-------------:|-------------:|-------------:|-------------:|-------------:|-------------:|-------------:|-------------:|
# |04822305_2817_1281_3073_1537|133.0| 100.0| 0.0| 16151.0| 0.0| 0.0| 0.0| 0.98577880859375| 0.0|
# |04822305_2817_2049_3073_2305|13.0| 76.0| 0.0| 16295.0| 0.0| 0.0| 0.0| 0.99456787109375| 0.0|
# |04822305_2817_5121_3073_5377|301.0| 344.0| 0.0| 15739.0| 0.0| 0.0| 0.0| 0.96063232421875| 0.0|
# |04822305_2817_6657_3073_6913|0.0| 87.0| 0.0| 16297.0| 0.0| 0.0| 0.0| 0.99468994140625| 0.0|
# |04822305_2817_6913_3073_7169|0.0| 90.0| 0.0| 16294.0| 0.0| 0.0| 0.0| 0.9945068359375| 0.0|
# |04822305_2817_7681_3073_7937|29.0| 154.0| 0.0| 16201.0| 0.0| 0.0| 0.0| 0.98883056640625| 0.0|
# |04822305_513_1281_769_1537|237.0| 160.0| 0.0| 15987.0| 0.0| 0.0| 0.0| 0.97576904296875| 0.0|
# |04822305_513_3073_769_3329|0.0| 123.0| 0.0| 16261.0| 0.0| 0.0| 0.0| 0.99249267578125| 0.0|
# |04822305_513_4097_769_4353|2.0| 122.0| 0.0| 16260.0| 0.0| 0.0| 0.0| 0.992431640625| 0.0|
# |04822305_769_1537_1025_1793|48.0| 189.0| 0.0| 16147.0| 0.0| 0.0| 0.0| 0.98553466796875| 0.0|
# |04822305_769_3841_1025_4097|0.0| 318.0| 0.0| 16066.0| 0.0| 0.0| 0.0| 0.9805908203125| 0.0|
# |49829545__1793_6913_2049_7169|0.0| 53.0| 0.0| 16331.0| 0.0| 0.0| 0.0| 0.99676513671875| 0.0|
#
# ### Total Stats
#
# | Image        | FP | FN | TP | TN| Wrong Label| Precision |Recall | Accuracy  | F-Score |
# |-------------|----------:|-------------:|-------------:|-------------:|-------------:|-------------:|-------------:|-------------:|-------------:|
# |Totals|21013.0| 102125.0| 392.0| 10198390.0| 0.0| 0.018313478159308574| 0.0038237560599705413| 0.9880702427455357| 0.00632656025564468|
#
# ## Scenario Convolution 5 Learning
#
#
# Learning turned on for conv5_1, conv5_2, conv5_3, fc6.
#
# Total Test net loss = 3331.6 (* 1 = 3331.6 loss)
# Total Test accuracy = 0.976814
#
# ### Sample Stats
#
# | Image        | FP | FN | TP | TN| Wrong Label| Precision |Recall | Accuracy  | F-Score |
# |-------------|----------:|-------------:|-------------:|-------------:|-------------:|-------------:|-------------:|-------------:|-------------:|
# |04822305_2817_1281_3073_1537|0.0| 100.0| 0.0| 16284.0| 0.0| 0.0| 0.0| 0.993896484375| 0.0|
# |04822305_2817_2049_3073_2305|0.0| 76.0| 0.0| 16308.0| 0.0| 0.0| 0.0| 0.995361328125| 0.0|
# |04822305_2817_5121_3073_5377|0.0| 344.0| 0.0| 16040.0| 0.0| 0.0| 0.0| 0.97900390625| 0.0|
# |04822305_2817_6657_3073_6913|0.0| 87.0| 0.0| 16297.0| 0.0| 0.0| 0.0| 0.99468994140625| 0.0|
# |04822305_2817_6913_3073_7169|0.0| 90.0| 0.0| 16294.0| 0.0| 0.0| 0.0| 0.9945068359375| 0.0|
# |04822305_2817_7681_3073_7937|0.0| 154.0| 0.0| 16230.0| 0.0| 0.0| 0.0| 0.9906005859375| 0.0|
# |04822305_513_1281_769_1537|0.0| 160.0| 0.0| 16224.0| 0.0| 0.0| 0.0| 0.990234375| 0.0|
# |04822305_513_3073_769_3329|0.0| 123.0| 0.0| 16261.0| 0.0| 0.0| 0.0| 0.99249267578125| 0.0|
# |04822305_513_4097_769_4353|0.0| 122.0| 0.0| 16262.0| 0.0| 0.0| 0.0| 0.9925537109375| 0.0|
# |04822305_769_1537_1025_1793|0.0| 189.0| 0.0| 16195.0| 0.0| 0.0| 0.0| 0.98846435546875| 0.0|
# |04822305_769_3841_1025_4097|0.0| 318.0| 0.0| 16066.0| 0.0| 0.0| 0.0| 0.9805908203125| 0.0|
# |49829545__1793_6913_2049_7169|0.0| 53.0| 0.0| 16331.0| 0.0| 0.0| 0.0| 0.99676513671875| 0.0|
#
# ### Total Stats
#
# | Image        | FP | FN | TP | TN| Wrong Label| Precision |Recall | Accuracy  | F-Score |
# |-------------|----------:|-------------:|-------------:|-------------:|-------------:|-------------:|-------------:|-------------:|-------------:|
# |Totals|21198.0| 101394.0| 1123.0| 10198205.0| 0.0| 0.05031136597822678| 0.010954280753436015| 0.9881231398809524| 0.017991316746503467|
#
# ## Scenario: Ignore Label
#
# Total Test net loss = 971.825 (* 1 = 971.825 loss)
# Total Test accuracy = 0.988202
#
# Learned background only
#
#
# # Five Label
#
# ## Create DB Configuration
# ```
# {
#    "dataDirectory": "/data/oirds",
#    "xlsInfoColumns" : [2,7,9],
#    "modes": ["VEHICLE/CAR","VEHICLE/PICK-UP","VEHICLE/TRUCK","VEHICLE/UNKNOWN","VEHICLE/VAN"],
#    "imageDirectory": "png",
#    "multiplicationFactor": 1,
#    "resize": 128,
#    "percentageToTest":0.18
# }
# ```
# ## Base Solver Configuration
#
# Learning Rate is le-11
# Learning Rate is fixed
# Momentum is 0.99
# Weight Decay is 0.0005
#
# ## Base Solver Configuration
#
# ```
# {
#    "modelFileName": "/data/oird_fcn/fcn-8s-pascalcontext.caffemodel",
#    "prototxt" : "solver.prototxt",
#    "netsurgery": true,
#    "steps":15000,
#    "gpu": true
# }
# ```
#
# ## Base Network Configuration
#
# Learning only on layers fc6, fc7, upscore2,score-pool4, upsample-fused-16, score-pool3 and score59.
# Normalization false for loss function.
#
# Number of outputs is 6, requiring modification/renaming of the following layers: score59, upscore2, score-pool3, score-pool3c, score-pool4, upsample-fused-16, upsample.  These layers do not have transfer learning.
